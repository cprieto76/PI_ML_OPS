# %% [markdown]
# # `PROYECTO INDIVIDUAL 1`
# ## `SISTEMA DE RECOMENDACION PELICULAS Y SERIES`

# %% [markdown]
# ## `pandas_dq`

# %%
import pandas as pd
import numpy as np
from pandas_dq import dq_report

# %%
# Importar archivo para trabajar
df = pd.read_csv('datafinal.csv')

# %%
## ` EDA. Analisis Exploratorio de Datos`

# %%
dqr = dq_report(df, html=False, csv_engine="pandas", verbose=1)
# Out:
# <style type="text/css">
# #T_0feb8_row0_col0, #T_0feb8_row0_col2, #T_0feb8_row0_col5, #T_0feb8_row1_col0, #T_0feb8_row1_col2, #T_0feb8_row1_col5, #T_0feb8_row2_col0, #T_0feb8_row2_col2, #T_0feb8_row2_col5, #T_0feb8_row3_col0, #T_0feb8_row3_col2, #T_0feb8_row3_col5, #T_0feb8_row4_col0, #T_0feb8_row4_col2, #T_0feb8_row4_col5, #T_0feb8_row5_col0, #T_0feb8_row5_col2, #T_0feb8_row5_col5, #T_0feb8_row6_col0, #T_0feb8_row6_col2, #T_0feb8_row6_col5, #T_0feb8_row7_col0, #T_0feb8_row7_col2, #T_0feb8_row7_col5, #T_0feb8_row8_col0, #T_0feb8_row8_col2, #T_0feb8_row8_col5, #T_0feb8_row9_col0, #T_0feb8_row9_col2, #T_0feb8_row9_col5, #T_0feb8_row10_col0, #T_0feb8_row10_col2, #T_0feb8_row10_col5, #T_0feb8_row11_col0, #T_0feb8_row11_col2, #T_0feb8_row11_col5, #T_0feb8_row12_col0, #T_0feb8_row12_col2, #T_0feb8_row12_col5, #T_0feb8_row13_col0, #T_0feb8_row13_col2, #T_0feb8_row13_col5, #T_0feb8_row14_col0, #T_0feb8_row14_col2, #T_0feb8_row14_col5, #T_0feb8_row15_col0, #T_0feb8_row15_col2, #T_0feb8_row15_col5, #T_0feb8_row16_col0, #T_0feb8_row16_col2, #T_0feb8_row16_col5, #T_0feb8_row17_col0, #T_0feb8_row17_col2, #T_0feb8_row17_col5, #T_0feb8_row18_col0, #T_0feb8_row18_col2, #T_0feb8_row18_col5, #T_0feb8_row19_col0, #T_0feb8_row19_col2, #T_0feb8_row19_col5, #T_0feb8_row20_col0, #T_0feb8_row20_col2, #T_0feb8_row20_col5, #T_0feb8_row21_col0, #T_0feb8_row21_col2, #T_0feb8_row21_col5, #T_0feb8_row22_col0, #T_0feb8_row22_col2, #T_0feb8_row22_col5, #T_0feb8_row23_col0, #T_0feb8_row23_col2, #T_0feb8_row23_col5, #T_0feb8_row24_col0, #T_0feb8_row24_col2, #T_0feb8_row24_col5, #T_0feb8_row25_col0, #T_0feb8_row25_col2, #T_0feb8_row25_col5, #T_0feb8_row26_col0, #T_0feb8_row26_col2, #T_0feb8_row26_col5 {
#   font-family: Segoe UI;
# }
# #T_0feb8_row0_col1, #T_0feb8_row0_col3, #T_0feb8_row0_col4, #T_0feb8_row1_col1, #T_0feb8_row3_col1, #T_0feb8_row3_col3, #T_0feb8_row3_col4, #T_0feb8_row4_col1, #T_0feb8_row4_col3, #T_0feb8_row4_col4, #T_0feb8_row5_col1, #T_0feb8_row5_col3, #T_0feb8_row5_col4, #T_0feb8_row6_col1, #T_0feb8_row7_col1, #T_0feb8_row8_col1, #T_0feb8_row8_col3, #T_0feb8_row8_col4, #T_0feb8_row9_col1, #T_0feb8_row9_col3, #T_0feb8_row10_col1, #T_0feb8_row10_col3, #T_0feb8_row12_col4, #T_0feb8_row18_col1, #T_0feb8_row18_col4, #T_0feb8_row19_col1, #T_0feb8_row19_col3, #T_0feb8_row24_col1, #T_0feb8_row25_col1, #T_0feb8_row26_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row1_col3, #T_0feb8_row1_col4, #T_0feb8_row2_col3, #T_0feb8_row2_col4, #T_0feb8_row6_col3, #T_0feb8_row6_col4, #T_0feb8_row7_col3, #T_0feb8_row7_col4, #T_0feb8_row11_col3, #T_0feb8_row11_col4, #T_0feb8_row13_col3, #T_0feb8_row13_col4, #T_0feb8_row14_col3, #T_0feb8_row14_col4, #T_0feb8_row15_col3, #T_0feb8_row15_col4, #T_0feb8_row16_col3, #T_0feb8_row16_col4, #T_0feb8_row17_col3, #T_0feb8_row17_col4, #T_0feb8_row20_col3, #T_0feb8_row20_col4, #T_0feb8_row21_col3, #T_0feb8_row21_col4, #T_0feb8_row22_col3, #T_0feb8_row22_col4, #T_0feb8_row23_col3, #T_0feb8_row23_col4, #T_0feb8_row24_col3, #T_0feb8_row24_col4, #T_0feb8_row25_col3, #T_0feb8_row25_col4, #T_0feb8_row26_col3, #T_0feb8_row26_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0feb8_row2_col1 {
#   background-color: #fff2eb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row9_col4 {
#   background-color: #fedecf;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row10_col4, #T_0feb8_row12_col1, #T_0feb8_row13_col1, #T_0feb8_row14_col1, #T_0feb8_row15_col1, #T_0feb8_row18_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0feb8_row11_col1 {
#   background-color: #f24734;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0feb8_row12_col3, #T_0feb8_row19_col4 {
#   background-color: #fff4ef;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row16_col1, #T_0feb8_row17_col1 {
#   background-color: #fee6da;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row20_col1, #T_0feb8_row21_col1 {
#   background-color: #fcae92;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0feb8_row22_col1, #T_0feb8_row23_col1 {
#   background-color: #fedaca;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_0feb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0feb8_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_0feb8_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_0feb8_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_0feb8_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_0feb8_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_0feb8_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0feb8_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_0feb8_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_0feb8_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0feb8_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_0feb8_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_0feb8_row0_col4" class="data row0 col4" >469172.000000</td>
#       <td id="T_0feb8_row0_col5" class="data row0 col5" >Possible ID colum: drop before modeling process., has 2480 outliers greater than upper bound (351918.38) or lower than lower bound(-168926.62). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0feb8_level0_row1" class="row_heading level0 row1" >title</th>
#       <td id="T_0feb8_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_0feb8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0feb8_row1_col2" class="data row1 col2" >93</td>
#       <td id="T_0feb8_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_0feb8_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_0feb8_row1_col5" class="data row1 col5" >42196 rare categories: Too many to list. Group them into a single category or drop the categories., high cardinality with 42196 unique values: Use hash encoding or embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_0feb8_level0_row2" class="row_heading level0 row2" >overview</th>
#       <td id="T_0feb8_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_0feb8_row2_col1" class="data row2 col1" >2.086182</td>
#       <td id="T_0feb8_row2_col2" class="data row2 col2" >97</td>
#       <td id="T_0feb8_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_0feb8_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_0feb8_row2_col5" class="data row2 col5" >946 missing values. Impute them with mean, median, mode, or a constant value such as 123., 44231 rare categories: Too many to list. Group them into a single category or drop the categories., Mixed dtypes: has 2 different data types:  object, float,, high cardinality with 44231 unique values: Use hash encoding or embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_0feb8_level0_row3" class="row_heading level0 row3" >popularity</th>
#       <td id="T_0feb8_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_0feb8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_0feb8_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_0feb8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_0feb8_row3_col4" class="data row3 col4" >547.488298</td>
#       <td id="T_0feb8_row3_col5" class="data row3 col5" >has 4210 outliers greater than upper bound (8.64) or lower than lower bound(-4.56). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_0feb8_level0_row4" class="row_heading level0 row4" >vote_average</th>
#       <td id="T_0feb8_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_0feb8_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_0feb8_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_0feb8_row4_col3" class="data row4 col3" >0.000000</td>
